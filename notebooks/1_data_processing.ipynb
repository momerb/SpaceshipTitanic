# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/graph.csv')

df
# Out:
#        PassengerGroup HomePlanet  HomePlanetValueAvail CryoSleep  \
# 0                   1     Europa                   NaN     False
# 1                   2      Earth                   NaN     False
# 2                   3     Europa                   NaN     False
# 3                   3     Europa                   NaN     False
# 4                   4      Earth                   NaN     False
# ...               ...        ...                   ...       ...
# 12965            9266      Earth                   NaN      True
# 12966            9269      Earth                   NaN     False
# 12967            9271       Mars                   NaN      True
# 12968            9273     Europa                   NaN     False
# 12969            9277      Earth                   NaN      True
#
#        CryoSleepValueAvail CabinDeck CabinSide    Destination   Age    VIP  \
# 0                      NaN         B         P    TRAPPIST-1e  39.0  False
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['MoneySpent'], df['Age'], color='blue', alpha=0.7)
plt.title('Comparison of Age and Money Spent')
plt.xlabel('Age')
plt.ylabel('Money Spent')
plt.grid(True)
plt.show()

# %% [markdown]
# The graph shows that age < 14 has 0 spent, so this information can be used to predict the missing values of 'MoneySpent' atleast for the age less than 14, for age greater than 14, we will have to take the Median.
